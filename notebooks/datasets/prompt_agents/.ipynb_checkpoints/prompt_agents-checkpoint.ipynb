# %%
west_coast_clients = {
    "client11": {
        "o": 3,
        "c": 4,
        "e": 2,
        "a": 5,
        "n": 2,
        "education": "Bachelor's degree",
        "current_work": "Software Engineer",
        "ethnicity": "Latino/Hispanic",
        "income_bracket": "$60,000-$80,000",
        "age": 30,
        "sexual_orientation": "Gay",
        "favorite_movies": ["Coco", "Selena"],
        "favorite_tv_shows": ["One Day at a Time", "Gentefied"],
        "comment": "I'm looking for an AI solution to help me optimize my code and improve software development efficiency."
    },
    "client12": {
        "o": 4,
        "c": 3,
        "e": 4,
        "a": 4,
        "n": 3,
        "education": "Master's degree",
        "current_work": "Marketing Manager",
        "ethnicity": "Asian American",
        "income_bracket": "$70,000-$90,000",
        "age": 35,
        "sexual_orientation": "Heterosexual",
        "favorite_movies": ["Crazy Rich Asians", "Mulan"],
        "favorite_tv_shows": ["Fresh Off the Boat", "Kim's Convenience"],
        "comment": "I need an AI assistant to analyze market trends and customer behavior for more effective marketing strategies."
    },
    "client13": {
        "o": 2,
        "c": 5,
        "e": 3,
        "a": 2,
        "n": 4,
        "education": "PhD",
        "current_work": "Data Scientist",
        "ethnicity": "Pacific Islander",
        "income_bracket": "$80,000-$100,000",
        "age": 29,
        "sexual_orientation": "Bisexual",
        "favorite_movies": ["Moana", "Lilo & Stitch"],
        "favorite_tv_shows": ["Hawai'i Five-0", "Finding 'Ohana"],
        "comment": "I'm interested in an AI tool that can help me analyze large datasets and extract valuable insights for my research projects."
    },
    "client14": {
        "o": 5,
        "c": 2,
        "e": 5,
        "a": 1,
        "n": 4,
        "education": "Bachelor's degree",
        "current_work": "Entrepreneur",
        "ethnicity": "Native American",
        "income_bracket": "$50,000-$70,000",
        "age": 31,
        "sexual_orientation": "Two-Spirit",
        "favorite_movies": ["Smoke Signals", "Dreamkeeper"],
        "favorite_tv_shows": ["Rutherford Falls", "Reservation Dogs"],
        "comment": "I'm seeking an AI solution to help streamline operations and customer interactions in my small business."
    },
    "client15": {
        "o": 3,
        "c": 3,
        "e": 4,
        "a": 5,
        "n": 2,
        "education": "High school diploma",
        "current_work": "Retail Associate",
        "ethnicity": "African American",
        "income_bracket": "$25,000-$35,000",
        "age": 24,
        "sexual_orientation": "Heterosexual",
        "favorite_movies": ["Black Panther", "Hidden Figures"],
        "favorite_tv_shows": ["Insecure", "Black-ish"],
        "comment": "I'm interested in an AI solution that can help me manage inventory and customer inquiries at my retail job."
    },
    "client16": {
        "o": 4,
        "c": 4,
        "e": 3,
        "a": 3,
        "n": 3,
        "education": "Master's degree",
        "current_work": "Architect",
        "ethnicity": "Middle Eastern",
        "income_bracket": "$90,000-$110,000",
        "age": 33,
        "sexual_orientation": "Heterosexual",
        "favorite_movies": ["A Separation", "Theeb"],
        "favorite_tv_shows": ["Ramy", "Tyrant"],
        "comment": "I'm looking for an AI assistant to help me design and simulate architectural structures more efficiently."
    },
    "client17": {
        "o": 2,
        "c": 5,
        "e": 2,
        "a": 4,
        "n": 4,
        "education": "PhD",
        "current_work": "Environmental Scientist",
        "ethnicity": "Indigenous",
        "income_bracket": "$60,000-$80,000",
        "age": 30,
        "sexual_orientation": "Pansexual",
        "favorite_movies": ["Frozen River", "Neither Wolf Nor Dog"],
        "favorite_tv_shows": ["Tribal", "Molly of Denali"],
        "comment": "I'm interested in an AI tool that can help me analyze environmental data and predict ecological trends."
    },
    "client18": {
        "o": 5,
        "c": 3,
        "e": 4,
        "a": 2,
        "n": 2,
        "education": "Bachelor's degree",
        "current_work": "Music Producer",
        "ethnicity": "Multiracial",
        "income_bracket": "$40,000-$60,000",
        "age": 27,
        "sexual_orientation": "Queer",
        "favorite_movies": ["La La Land", "Crazy, Stupid, Love."],
        "favorite_tv_shows": ["Empire", "Beats"],
        "comment": "I'm seeking an AI tool that can assist me in composing and producing music with innovative sounds."
    },
    "client19": {
        "o": 3,
        "c": 4,
        "e": 3,
        "a": 4,
        "n": 3,
        "education": "Master's degree",
        "current_work": "Clinical Psychologist",
        "ethnicity": "Asian American",
        "income_bracket": "$70,000-$90,000",
        "age": 34,
        "sexual_orientation": "Heterosexual",
        "favorite_movies": ["Good Will Hunting", "Silver Linings Playbook"],
        "favorite_tv_shows": ["In Treatment", "Mindhunter"],
        "comment": "I'm looking for an AI tool to assist me in analyzing patient data and identifying patterns in psychological assessments."
    },
    "client20": {
        "o": 4,
        "c": 3,
        "e": 4,
        "a": 3,
        "n": 4,
        "education": "PhD",
        "current_work": "Film Director",
        "ethnicity": "Latino/Hispanic",
        "income_bracket": "$80,000-$100,000",
        "age": 32,
        "sexual_orientation": "Bisexual",
        "favorite_movies": ["Roma", "Y Tu Mamá También"],
        "favorite_tv_shows": ["Narcos", "On My Block"],
        "comment": "I'm interested in an AI tool that can help me analyze scripts and predict audience reactions for my film projects."
    }
}

# %%
east_coast_clients = {
    "client1": {
        "o": 3,
        "c": 4,
        "e": 2,
        "a": 5,
        "n": 2,
        "education": "Master's",
        "current_work": "Software Engineer",
        "ethnicity": "Asian",
        "income_bracket": "$60,000-$80,000",
        "age": 30,
        "sexual_orientation": "Bisexual",
        "favorite_movies": ["Spirited Away", "Parasite"],
        "favorite_tv_shows": ["Mindhunter", "Black Mirror"],
        "comment": "I'm looking for an AI assistant that can help me optimize my coding process and suggest innovative solutions."
    },
    "client2": {
        "o": 4,
        "c": 3,
        "e": 5,
        "a": 2,
        "n": 5,
        "education": "Bachelor's",
        "current_work": "Entrepreneur",
        "ethnicity": "Hispanic",
        "income_bracket": "$100,000-$150,000",
        "age": 35,
        "sexual_orientation": "Gay",
        "favorite_movies": ["Coco", "In the Heights"],
        "favorite_tv_shows": ["Shark Tank", "Narcos"],
        "comment": "I need an AI tool that can assist me in analyzing market trends and identifying business growth opportunities."
    },
    "client3": {
        "o": 2,
        "c": 5,
        "e": 3,
        "a": 4,
        "n": 3,
        "education": "PhD",
        "current_work": "Psychologist",
        "ethnicity": "Native American",
        "income_bracket": "$70,000-$90,000",
        "age": 40,
        "sexual_orientation": "Two-Spirit",
        "favorite_movies": ["Smoke Signals", "Windtalkers"],
        "favorite_tv_shows": ["Mindhunter", "The Crown"],
        "comment": "I'm interested in an AI solution that can assist me in analyzing patient data and providing insights for my research in mental health."
    },
    "client4": {
        "o": 5,
        "c": 1,
        "e": 4,
        "a": 3,
        "n": 4,
        "education": "Bachelor's",
        "current_work": "Artist",
        "ethnicity": "Pacific Islander",
        "income_bracket": "$30,000-$40,000",
        "age": 25,
        "sexual_orientation": "Queer",
        "favorite_movies": ["Moana", "Lilo & Stitch"],
        "favorite_tv_shows": ["Abstract", "Queer Eye"],
        "comment": "I'm looking for an AI assistant that can help me generate new artistic ideas and suggest unique techniques."
    },
    "client5": {
        "o": 3,
        "c": 3,
        "e": 2,
        "a": 4,
        "n": 5,
        "education": "High School",
        "current_work": "Retail Associate",
        "ethnicity": "Black",
        "income_bracket": "$20,000-$30,000",
        "age": 22,
        "sexual_orientation": "Lesbian",
        "favorite_movies": ["Hidden Figures", "The Color Purple"],
        "favorite_tv_shows": ["Superstore", "Black-ish"],
        "comment": "I'm interested in an AI tool that can help me with budgeting and finding discounts on essential items."
    },
    "client6": {
        "o": 4,
        "c": 4,
        "e": 3,
        "a": 5,
        "n": 2,
        "education": "Master's",
        "current_work": "Teacher",
        "ethnicity": "Asian",
        "income_bracket": "$50,000-$60,000",
        "age": 27,
        "sexual_orientation": "Heterosexual",
        "favorite_movies": ["Dead Poets Society", "Mulan"],
        "favorite_tv_shows": ["The Crown", "Stranger Things"],
        "comment": "I'm seeking an AI assistant that can help me develop engaging lesson plans and provide educational resources."
    },
    "client7": {
        "o": 2,
        "c": 5,
        "e": 4,
        "a": 3,
        "n": 4,
        "education": "PhD",
        "current_work": "Medical Researcher",
        "ethnicity": "Hispanic",
        "income_bracket": "$80,000-$100,000",
        "age": 32,
        "sexual_orientation": "Pansexual",
        "favorite_movies": ["The Shape of Water", "Coco"],
        "favorite_tv_shows": ["House", "Grey's Anatomy"],
        "comment": "I'm looking for an AI tool that can assist me in analyzing complex medical data and identifying potential breakthroughs."
    },
    "client8": {
        "o": 5,
        "c": 2,
        "e": 4,
        "a": 3,
        "n": 4,
        "education": "Bachelor's",
        "current_work": "Social Worker",
        "ethnicity": "Black",
        "income_bracket": "$40,000-$50,000",
        "age": 29,
        "sexual_orientation": "Asexual",
        "favorite_movies": ["The Help", "Hidden Figures"],
        "favorite_tv_shows": ["This Is Us", "The Good Place"],
        "comment": "I'm interested in an AI solution that can help me organize case files and suggest appropriate interventions for clients."
    },
    "client9": {
        "o": 3,
        "c": 4,
        "e": 3,
        "a": 4,
        "n": 2,
        "education": "Master's",
        "current_work": "Marketing Specialist",
        "ethnicity": "Asian",
        "income_bracket": "$70,000-$90,000",
        "age": 31,
        "sexual_orientation": "Heterosexual",
        "favorite_movies": ["Crazy Rich Asians", "The Social Network"],
        "favorite_tv_shows": ["Mad Men", "Black Mirror"],
        "comment": "I'm seeking an AI assistant that can help me analyze consumer trends and optimize marketing campaigns."
    },
    "client10": {
        "o": 4,
        "c": 3,
        "e": 5,
        "a": 2,
        "n": 3,
        "education": "Bachelor's",
        "current_work": "Journalist",
        "ethnicity": "Native American",
        "income_bracket": "$50,000-$70,000",
        "age": 33,
        "sexual_orientation": "Bisexual",
        "favorite_movies": ["Wind River", "Dances with Wolves"],
        "favorite_tv_shows": ["The Newsroom", "Frontline"],
        "comment": "I'm interested in an AI tool that can assist me in sifting through vast amounts of information and identifying news trends."
    }
}

# %%
from datasets import (
    Dataset,
    DatasetDict,
    DownloadMode,
    get_dataset_split_names,
    load_dataset,
    load_dataset_builder,
)

# %%
dict_dataset = {k:[] for k in east_coast_clients["client1"].keys()}
dict_dataset = dict_dataset | {"id":[],"location":[]}

for client, client_dict in west_coast_clients.items():
    for k,v in client_dict.items():
        dict_dataset[k].append(v)
    dict_dataset["id"].append(client)
    dict_dataset["location"].append("west_coast")

for client, client_dict in east_coast_clients.items():
    for k,v in client_dict.items():
        dict_dataset[k].append(v)
    dict_dataset["id"].append(client)
    dict_dataset["location"].append("east_coast")

# %%
dataset = Dataset.from_dict(dict_dataset)

# %%
dataset[0]
# Out:
# {'o': 3,
#  'c': 4,
#  'e': 2,
#  'a': 5,
#  'n': 2,
#  'education': "Bachelor's degree",
#  'current_work': 'Software Engineer',
#  'ethnicity': 'Latino/Hispanic',
#  'income_bracket': '$60,000-$80,000',
#  'age': 30,
#  'sexual_orientation': 'Gay',
#  'favorite_movies': ['Coco', 'Selena'],
#  'favorite_tv_shows': ['One Day at a Time', 'Gentefied'],
#  'comment': "I'm looking for an AI solution to help me optimize my code and improve software development efficiency.",
#  'id': 'client11',
#  'location': 'west_coast'}

# %%
from huggingface_hub import login

# %%
login()

# %%
dataset.push_to_hub("cesarali/test_ocean_clients")
# Out:
# ...
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
